# %% [markdown]
# # Week-3

# %%
import pandas as pd
url = "https://fred.stlouisfed.org/graph/fredgraph.csv?id=MORTGAGE30US" 
mortgage = pd.read_csv(url, parse_dates=['observation_date']) 
mortgage.columns = ['date', 'rate_30yr_fixed']

# %%
# step 2 – Resample weekly rates to monthly averages 
mortgage['year_month'] = mortgage['date'].dt.to_period('M')
mortgage_monthly = (
    mortgage.groupby('year_month')['rate_30yr_fixed']
    .mean()
    .reset_index()
)
print(mortgage_monthly.head())
# Out:
#   year_month  rate_30yr_fixed
# 0    1971-04           7.3100
# 1    1971-05           7.4250
# 2    1971-06           7.5300
# 3    1971-07           7.6040
# 4    1971-08           7.6975

# %%
# Step 3 – Create a matching year_month key on the MLS datasets
# Sold dataset — key off CloseDate 
import pandas as pd
sold = pd.read_csv("CRMLSSold_residential.csv")
sold['year_month'] = pd.to_datetime(sold['CloseDate']).dt.to_period('M')
#step 4 - Merge
sold_with_rates = sold.merge(mortgage_monthly, on='year_month', how='left')
# Step 5 – Validate the merge 
sold_with_rates['rate_30yr_fixed'].isnull().sum()
print("Missing rates in sold:", sold_with_rates["rate_30yr_fixed"].isnull().sum())
# Out:
# /var/folders/d_/gll3jlg1445_2nm3xgq_xvdc0000gn/T/ipykernel_27443/3433635961.py:4: DtypeWarning: Columns (0: BuyerAgentAOR, 1: ListAgentAOR, 2: ListAgentEmail, 3: FireplaceYN, 4: OriginatingSystemName, 5: OriginatingSystemSubName, 6: BuyerAgencyCompensationType, 7: latfilled, 8: lonfilled) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold = pd.read_csv("CRMLSSold_residential.csv")
# Missing rates in sold: 0

# %%
sold_with_rates[['CloseDate', 'year_month', 'ClosePrice', 'rate_30yr_fixed']].head()
# Out:
#     CloseDate year_month  ClosePrice  rate_30yr_fixed
# 0  2024-01-26    2024-01    240000.0           6.6425
# 1  2024-01-05    2024-01    815000.0           6.6425
# 2  2024-01-05    2024-01    810000.0           6.6425
# 3  2024-01-30    2024-01    858000.0           6.6425
# 4  2024-01-29    2024-01   1890500.0           6.6425
